# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Read Dataset

# %%
books_df = pd.read_excel('datasets/Amazon_top100_bestselling_books_2009to2021.xlsx')

# %%
books_df.head()
# Out:
#    Unnamed: 0  price  ranks                                          title  \
# 0           0  12.49    1.0                                The Lost Symbol
# 1           1  13.40    2.0    The Shack: Where Tragedy Confronts Eternity
# 2           2   9.93    3.0  Liberty and Tyranny: A Conservative Manifesto
# 3           3  14.30    4.0      Breaking Dawn (The Twilight Saga, Book 4)
# 4           4   9.99    5.0                  Going Rogue: An American Life
#
#    no_of_reviews  ratings            author cover_type  year        genre
# 0        16118.0      4.4         Dan Brown  Hardcover  2009      Fiction
# 1        23392.0      4.7  William P. Young  Paperback  2009      Fiction
# 2         5036.0      4.8     Mark R. Levin  Hardcover  2009  Non Fiction
# 3        16912.0      4.7   Stephenie Meyer  Hardcover  2009      Fiction
# 4         1572.0      4.6       Sarah Palin  Hardcover  2009  Non Fiction

# %% [markdown]
# # Data Analysis

# %%
books_df.shape
# Out:
# (1291, 10)

# %%
books_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1291 entries, 0 to 1290
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1291 non-null   int64
#  1   price          1287 non-null   float64
#  2   ranks          1287 non-null   float64
#  3   title          1286 non-null   object
#  4   no_of_reviews  1287 non-null   float64
#  5   ratings        1287 non-null   float64
#  6   author         1286 non-null   object
#  7   cover_type     1286 non-null   object
#  8   year           1291 non-null   int64
#  9   genre          1288 non-null   object
# dtypes: float64(4), int64(2), object(4)
# memory usage: 101.0+ KB

# %%
books_df.describe().T.round(2)
# Out:
#                 count      mean       std      min      25%      50%  \
# Unnamed: 0     1291.0    645.00    372.82     0.00   322.50    645.0
# price          1287.0     13.76     10.05     1.17     8.55     12.1
# ranks          1287.0     50.25     28.80     1.00    25.00     50.0
# no_of_reviews  1287.0  25827.71  32224.06    50.00  6769.00  16845.0
# ratings        1287.0      4.65      0.20     3.40     4.60      4.7
# year           1291.0   2015.03      3.73  2009.00  2012.00   2015.0
#
#                     75%       max
# Unnamed: 0       967.50    1290.0
# price             16.29     144.0
# ranks             75.00     100.0
# no_of_reviews  32326.00  344811.0
# ratings            4.80       4.9
# year            2018.00    2021.0

# %% [markdown]
# ## Missed Value Problem

# %%
books_df.isnull().sum()
# Out:
# Unnamed: 0       0
# price            4
# ranks            4
# title            5
# no_of_reviews    4
# ratings          4
# author           5
# cover_type       5
# year             0
# genre            3
# dtype: int64

# %%
books_df.isnull().values.sum()
# Out:
# 34

# %%
books_df.interpolate(method='linear', limit_direction='forward', inplace=True, axis=0)

# %%
numeric_cols = books_df.select_dtypes(np.number).columns

# %%
numeric_cols
# Out:
# Index(['Unnamed: 0', 'price', 'ranks', 'no_of_reviews', 'ratings', 'year'], dtype='object')

# %%
books_df = books_df.fillna(books_df.median())
# Out:
# F:\4.yil_birinci_dnem\Data Science\data\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.

# %%
books_df.dropna(axis=0, inplace=True)

# %%
books_df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
books_df['author'].value_counts()
# Out:
# Rick Riordan             20
# Jeff Kinney              17
# Suzanne Collins          17
# John Grisham             15
# Gary Chapman             13
#                          ..
# Frank Berrios             1
# Justin Halpern            1
# John Steinbeck            1
# Keith Richards            1
# Doctor Joseph Mercola     1
# Name: author, Length: 502, dtype: int64

# %%
books_df['cover_type'].value_counts()
# Out:
# Hardcover                642
# Paperback                527
# Board book                80
# Mass Market Paperback     29
# Cards                      4
# Spiral-bound               1
# Printed Access Code        1
# Pamphlet                   1
# Name: cover_type, dtype: int64

# %% [markdown]
# ## Convert Data Type

# %%
books_df['no_of_reviews'] = books_df['no_of_reviews'].astype(np.float64)

# %%
books_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1285 entries, 0 to 1290
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          1285 non-null   float64
#  1   ranks          1285 non-null   float64
#  2   title          1285 non-null   object
#  3   no_of_reviews  1285 non-null   float64
#  4   ratings        1285 non-null   float64
#  5   author         1285 non-null   object
#  6   cover_type     1285 non-null   object
#  7   year           1285 non-null   int64
#  8   genre          1285 non-null   object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 100.4+ KB

# %%
books_df['no_of_reviews']
# Out:
# 0       16118.0
# 1       23392.0
# 2        5036.0
# 3       16912.0
# 4        1572.0
#          ...
# 1286    21401.0
# 1287    79872.0
# 1288    15753.0
# 1289     7246.0
# 1290    27332.0
# Name: no_of_reviews, Length: 1285, dtype: float64

# %%
def density_plot(dataframe, col):
    plt.figure(figsize=(12, 6))
    sns.kdeplot(dataframe[col], color='green', fill=True)

# %%
sns.kdeplot(books_df['no_of_reviews'], color='green', fill=True)
# Out:
# <AxesSubplot:xlabel='no_of_reviews', ylabel='Density'>

# %%
density_plot(books_df, 'price')

# %%
density_plot(books_df, 'ranks')

# %%
density_plot(books_df, 'ratings')

# %%
sns.scatterplot(x=books_df.price, y=books_df.ranks, hue=books_df.genre)
# Out:
# <AxesSubplot:xlabel='price', ylabel='ranks'>

# %%
sns.scatterplot(x=books_df.price, y=books_df.ratings, hue=books_df.genre)
# Out:
# <AxesSubplot:xlabel='price', ylabel='ratings'>

# %%
books_df.duplicated(keep='first').sum()
# Out:
# 0

# %%
books_df.groupby('year')['price', 'ranks', 'ratings'].sum()
# Out:
# F:\4.yil_birinci_dnem\Data Science\data\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#         price   ranks  ratings
# year
# 2009  1619.75  4851.0    444.0
# 2010  1541.22  4801.0    443.7
# 2011  1642.22  5000.0    453.5
# 2012  1652.50  4952.0    453.3
# 2013  1673.76  5050.0    459.2
# 2014  1534.82  5000.0    460.7
# 2015  1271.10  5050.0    465.7
# 2016  1133.84  4910.0    460.0
# 2017  1147.61  4973.0    464.1
# 2018  1215.55  4950.0    464.0
# 2019  1076.77  4953.0    465.9
# 2020  1041.70  5050.0    473.8
# 2021  1135.70  4982.0    468.5

# %%
book_year_mean = books_df.groupby('year')['price', 'ranks', 'ratings'].mean()
# Out:
# F:\4.yil_birinci_dnem\Data Science\data\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
book_year_mean
# Out:
#           price      ranks   ratings
# year
# 2009  16.698454  50.010309  4.577320
# 2010  15.888866  49.494845  4.574227
# 2011  16.588081  50.505051  4.580808
# 2012  16.691919  50.020202  4.578788
# 2013  16.737600  50.500000  4.592000
# 2014  15.503232  50.505051  4.653535
# 2015  12.711000  50.500000  4.657000
# 2016  11.569796  50.102041  4.693878
# 2017  11.592020  50.232323  4.687879
# 2018  12.278283  50.000000  4.686869
# 2019  10.876465  50.030303  4.706061
# 2020  10.417000  50.500000  4.738000
# 2021  11.471717  50.323232  4.732323

# %%
price_year_mean = books_df.groupby('year')[['price']].mean()

# %%
price_year_mean
# Out:
#           price
# year
# 2009  16.698454
# 2010  15.888866
# 2011  16.588081
# 2012  16.691919
# 2013  16.737600
# 2014  15.503232
# 2015  12.711000
# 2016  11.569796
# 2017  11.592020
# 2018  12.278283
# 2019  10.876465
# 2020  10.417000
# 2021  11.471717

# %%
price_year_mean.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
plt.hist(price_year_mean)
# Out:
# (array([2., 3., 1., 1., 0., 0., 0., 0., 2., 4.]),
#  array([10.417  , 11.04906, 11.68112, 12.31318, 12.94524, 13.5773 ,
#         14.20936, 14.84142, 15.47348, 16.10554, 16.7376 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(12, 6))
plt.title('Year Price Mean')
plt.bar(price_year_mean.index, price_year_mean.price)
plt.xlabel('Year')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='year', y='price', data=books_df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='price'>

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='year', y='ranks', data=books_df, hue='genre')
# Out:
# <AxesSubplot:xlabel='year', ylabel='ranks'>

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='year', y='ratings', data=books_df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='ratings'>

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='year', y='ratings', data=books_df, hue='genre')
# Out:
# <AxesSubplot:xlabel='year', ylabel='ratings'>

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='year', y='ratings', data=books_df, hue='genre')
# Out:
# <AxesSubplot:xlabel='year', ylabel='ratings'>

# %% [markdown]
# ## Correlation

# %%
correlation = books_df.corr(method='pearson')

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(correlation, annot=True, fmt='.2f')
plt.title('Pearson Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Pearson Correlation Matrix')

# %% [markdown]
# ## Data Visualization

# %%
sns.scatterplot(x=books_df.price, y=books_df.no_of_reviews)
# Out:
# <AxesSubplot:xlabel='price', ylabel='no_of_reviews'>

# %%
sns.scatterplot(x=books_df.price, y=books_df.no_of_reviews, hue=books_df.genre)
# Out:
# <AxesSubplot:xlabel='price', ylabel='no_of_reviews'>

# %%
books_df.author.unique()
# Out:
# array(['Dan Brown', 'William P. Young', 'Mark R. Levin',
#        'Stephenie Meyer', 'Sarah Palin', 'Gallup', 'Kathryn Stockett',
#        'Malcolm Gladwell', 'Glenn Beck', 'Greg Mortenson',
#        'Stephen Kendrick', 'Steve Harvey', 'Jeff Kinney', 'Stephen King',
#        'Mary Ann Shaffer', 'David Zinczenko', 'Julia Child',
#        'Charlaine Harris', 'Audrey Niffenegger',
#        'American Psychological Association', 'Edward M. Kennedy',
#        'Stieg Larsson', 'W. Cleon Skousen', 'Jim Collins',
#        'Maurice Sendak', 'Patrick Lencioni', 'Elizabeth Strout',
#        'Steven D. Levitt', 'Francis Chan', 'Rick Riordan',
#        'Muriel Barbery', 'James Patterson', 'Randy Pausch',
#        'Gary Chapman', 'Alan Moore', 'Stephen R. Covey', 'Bill Simmons',
#        'Zhi Gang Sha', 'Andre Agassi', 'Jane Austen',
#        'Lifetime Television,', 'Lisa Lillien', 'Christopher McDougall',
#        "Bill O'Reilly", 'Ree Drummond', 'Markus Zusak', 'Pat Conroy',
#        'Michael Pollan', 'Jillian Michaels', 'John Grisham',
#        'Michelle Malkin', 'Neil Gaiman', 'Diana Gabaldon',
#        'Robert Jordan', 'Barack Obama', 'Michael Crichton',
#        'The College Board', 'David Allen', 'Dale Carnegie',
#        'Janet Evanovich', 'Tatiana de Rosnay', 'Hilary Mantel',
#        'Suzanne Collins', 'Joe Torre', 'Sapphire', 'David Kessler',
#        'Barbara Kingsolver', 'Kerry Patterson', 'Nicholas D. Kristof',
#        'Jeff Hertzberg', 'Sarah Thomson', 'Vince Flynn',
#        'Nicholas Sparks', 'Ayn Rand', 'Aravind Adiga', 'Ron Hall',
#        'Sue Grafton', 'George W. Bush', 'Geneen Roth', 'Mark Twain',
#        'Michael Lewis', 'Laura Hillenbrand', 'Justin Halpern',
#        'Keith Richards', 'Abraham Verghese', 'Jon Stewart',
#        'John Heilemann', 'Rebecca Skloot', 'Doug Lemov', 'F. A. Hayek',
#        'Tony Hsieh', 'Larry Schweikart', 'Chip Heath', 'Garth Stein',
#        'Chris Cleave', 'Ina Garten', 'Peter A. Lillback', 'David Platt',
#        'Stacy Schiff', 'Jonathan Franzen', 'Ken Follett',
#        'Elizabeth Gilbert', 'Zhi Gang Sha Dr.', 'Chelsea Handler',
#        'Colum McCann', 'Jorge Cruise', 'Timothy Ferriss',
#        'Stephen Hawking', 'Sarah Young', 'Laura Bush', 'Mark Nepo',
#        'Daniel G. Amen', 'Alicia Silverstone', 'Jay-Z', 'Jeannette Walls',
#        'Jamie Ford', 'Nora Roberts', 'Project Management Institute',
#        'J. D. Salinger', 'Thomas Campbell', 'Jason Fried',
#        'David Sedaris', 'Spencer Johnson', 'Walter Isaacson',
#        'Todd Burpo', 'Christopher Paolini', 'Adam Mansbach',
#        'George R.R. Martin', 'Mike Moreno', 'George R. R. Martin',
#        'Tina Fey', 'Eric Larson', 'Jaycee Dugard', 'Sara Gruen',
#        'Daniel Lipkowitz', 'Ann Voskamp', 'Rob Bell', 'Daniel Kahneman',
#        'Paula McLain', 'Joel Fuhrman MD', 'Heidi Murkoff',
#        'Jacqueline Kennedy', 'David McCullough', 'Shel Silverstein',
#        'Ransom Riggs', 'Joshua Foer', 'F. Scott Fitzgerald',
#        'Haruki Murakami', 'Tom Rath', 'David Hodgson', 'Dr. Seuss',
#        'Tim Tebow', 'Jean M. Auel', 'David Brooks',
#        'Guinness World Records', 'Ann Patchett', 'Jennifer Egan',
#        'Caldwell B. Esselstyn Jr.', 'J. K. Rowling', 'Sean Covey',
#        'Emma Donoghue', 'Travis Bradberry', 'Gene Stone', 'Paulo Coelho',
#        'Brian Selznick', 'Daniel H. Pink', 'Moleskine Store',
#        'GMAC (Graduate Management Admission Council)', 'E L James',
#        'Mark Owen', 'Gillian Flynn', 'Eben Alexander', 'J.K. Rowling',
#        'Jonathan Cahn', 'Charles Duhigg', 'William Davis', 'Susan Cain',
#        'Mark Hyman M.D.', 'Sherri Duskey Rinker', 'John Green',
#        'Cheryl Strayed', 'Jon Meacham', 'Edward Klein', 'Deb Perelman',
#        'Robert Kirkman', 'Nate Silver', 'The Oatmeal', 'Stephen Colbert',
#        'DK Publishing', 'Chris Kyle', 'Sylvia Day', 'Don Miguel Ruiz',
#        'Katherine Boo', 'Sally Lloyd-Jones', 'David Mitchell',
#        'Anne Lamott', 'R. J. Palacio', 'Woo Myung', 'Mary C. Neal',
#        'Del Sroufe', 'Robert A. Caro', 'Timothy Keller', 'Elie Wiesel',
#        'Sheryl Sandberg', 'Rush Limbaugh', 'Charles Krauthammer',
#        'American Psychiatric Association', 'Veronica Roth', 'Rob Elliott',
#        'Khaled Hosseini', 'Brandon Stanton', 'Patrick Thorpe',
#        'Donna Tartt', 'Brian Kilmeade', 'Drew Daywalt', 'Phil Robertson',
#        'Eric Carle', 'Brené Brown', 'Ian K. Smith M.D.', 'Allie Brosh',
#        'Harper Lee', 'Orson Scott Card', 'Brené Brown',
#        'Robert Galbraith', 'Ben Carson  M.D.', 'Reza Aslan',
#        'Katherine Applegate', 'Si Robertson', 'Gwyneth Paltrow',
#        'Yotam Ottolenghi', 'Kelly Starrett', 'David Perlmutter MD',
#        'Malala Yousafzai', 'Robert Munsch', 'Stephen Chbosky',
#        'Diane Sanfilippo', 'Dr Dr Michael Mosley', 'Doris Kearns Goodwin',
#        'Nick J. Tate', 'J.D. Salinger', 'Carol S. Dweck',
#        'Hall H Pearson Education', 'Valorie Schaefer', 'Naoki Higashida',
#        'Kaplan', 'Phil McGraw', 'RH Disney', 'Randall Munroe', 'DK',
#        'B. J. Novak', 'Alice Schertle', 'Roger Priddy', 'Gayle Forman',
#        'Thomas Piketty', 'Christina Baker Kline', 'Anthony Doerr',
#        'Thug Kitchen', 'Daniel James Brown', 'James Dashner',
#        'Amy Poehler', 'Stephanie Milton', 'Melissa Lagonegro',
#        'Rod Campbell', 'Sandra Boynton', 'ACT', 'Sue Monk Kidd',
#        'William Golding', 'Gina Homolka', 'Ray Bradbury', 'Tom Robinson',
#        'George Orwell', 'S. E. Hinton', 'Tony Robbins',
#        'Margaret Wise Brown', 'Giles Andreae', 'Scholastic',
#        'John Steinbeck', 'JJ Smith', 'Frank Berrios', 'Lois Lowry',
#        'Bill Martin Jr.', 'Danielle Walker', 'Marie Kondō',
#        'Johanna Basford', 'Paula Hawkins', 'Blue Star Coloring',
#        'Coloring Books for Adults', 'Andy Weir', 'Marjorie Sarnat',
#        'Angie Grace', 'Atul Gawande', 'Ta-Nehisi Coates', 'Marty Noble',
#        'Kristin Hannah', 'Melissa Hartwig Urban', 'Zack Zombie',
#        'Laurence J. Kotlikoff', 'Adam Rubin', 'Leslie Patricelli',
#        'Erik Larson', 'Ali Maffucci', 'Alberta Hutchinson', 'Karen Katz',
#        'Sam McBratney', 'Valentina Harper', 'Jen Hatmaker',
#        'Herve Tullet', 'Linda Sue Park', 'Lilt Kids Coloring Books',
#        'Paul Kalanithi', 'Fredrik Backman', 'Chip Gaines', 'J. D. Vance',
#        'Lin-Manuel Miranda', 'Adult Coloring Book Designs', 'Rupi Kaur',
#        'Bruce Springsteen', 'Ron Chernow',
#        'Delegates of the Constitutional Convention',
#        'Emily Winfield Martin', 'Jen Sincero', 'Chrissy Teigen',
#        "Sasha O'Hara", 'Lysa TerKeurst', 'Priscilla Shirer',
#        'Ann Whitford Paul', 'Golden Books', 'Gary J. Byrne',
#        'Angela Duckworth', 'Colson Whitehead', 'J. Kenji López-Alt',
#        'Jojo Moyes', 'Thaneeya McArdle', 'Laurel Randolph',
#        'Darlene Schacht', 'Dungeons & Dragons', 'Mark Manson',
#        'Neil deGrasse Tyson', 'Margaret Atwood', 'Hillary Rodham Clinton',
#        'Admiral William H. McRaven', 'Amor Towles', 'Jay Asher',
#        'Deborah Diesen', 'Mr. Jim Kay', 'Adam Gasiewski', 'Ernest Cline',
#        'Dav Pilkey', 'Pete Souza', 'David Grann', 'Liane Moriarty',
#        'Oprah Winfrey', 'Naomi Kleinberg', 'Chelsea Clinton',
#        'Timothy Snyder', 'Yuval Noah Harari', 'Benjamin Graham',
#        'Dr. Steven R Gundry  MD', 'Nicola Yoon', 'Simon Sinek',
#        'Mark Sullivan', 'Martha Hall Kelly', 'Al Franken', 'Ray Dalio',
#        'Amy Ramos', 'Dave Ramsey', 'Andrea Beaty', 'Michelle Obama',
#        'Rachel Hollis', 'Craig Smith', 'Michael Wolff', 'Bob Woodward',
#        'Jill Twiss', 'Jordan B. Peterson', 'Joanna Gaines',
#        'The Staff of The Late Show with Stephen Colbert', 'James Comey',
#        'Tara Westover', 'Kevin Kwan', 'Angie Thomas', 'Paper Peony Press',
#        'Samin Nosrat', "Madeleine L'Engle", 'Jennifer Smith',
#        'Celeste Ng', 'Anthony Bourdain', 'School Zone', 'Tucker Carlson',
#        'Bob Goff', 'Lisa Wingate', 'Anthony William', 'Delia Owens',
#        'Wizards RPG', 'Yuval Harari', 'A. J. Finn', 'Suzanne Ryan',
#        'Jocko Willink', 'Gregg Jarrett', 'Dan Green', 'Jen Fisch',
#        'Brianna Caplan Sayres', 'Reese Witherspoon', 'Viktor E. Frankl',
#        'Bessel van der Kolk M.D.', 'Robert T. Kiyosaki', 'M Prefontaine',
#        'Adir Levy', 'Hopscotch Girls', 'Howard Stern', 'Raina Telgemeier',
#        'Amy Shields', 'Pretty Simple Press', 'Silly Bear',
#        'Nathan W. Pyle', 'Alex Michaelides', 'National Kids',
#        'Crispin Boyer', 'David Goggins', 'Dinah Bucholz',
#        'The Washington Post', 'Monica Sweeney', 'Brighter Child',
#        'James Clear', 'Richard Powers', 'Gail Honeyman', 'Elton John',
#        'Ian Morgan Cron', 'Heather Morris', 'Andrew Kipple',
#        "America's Test Kitchen Kids", 'Rachel Maddow', 'Dr. Jason Fung',
#        'Mary Pope Osborne', 'Lisa Jewell', 'Conor Riordan', 'Tish Rabe',
#        'Crazy Corey', 'Mary L. Trump Ph.D.', 'Crystal Radke',
#        'Glennon Doyle', 'Dr. Robin DiAngelo', 'John Bolton',
#        'Ibram X. Kendi', 'Isabel Wilkerson', 'Matthew McConaughey',
#        'Jeanine Cummins', 'Charlie Mackesy', 'Amelia Hepworth',
#        'Adam Wallace', 'Brit Bennett', 'Shannon Roberts',
#        'Workman Publishing', 'Carole P. Roman', 'Sean Hannity',
#        'Sharon Jones', 'Jennie Allen', 'Ph.D., Katie Stokes, M.Ed.,',
#        'Hoda Kotb', 'Bryan Stevenson', 'Deborah Schecter', 'Kobe Bryant',
#        'Michael Cohen', 'Tanya Emelyanova', 'Anna Dewdney', 'Ijeoma Oluo',
#        'Candace Owens', 'Crystal Chatterton', 'Eric Hill',
#        'Modern Kid Press', 'Michael Todd', 'Steve Doocy',
#        'Colleen Hoover', 'Matt Haig', 'Laura Dave',
#        'Robert F. Kennedy Jr.', 'Taylor Jenkins Reid', 'Robert Greene',
#        'Frank Herbert', 'Wonder House Books', 'Madeline Miller',
#        'Amanda Gorman', 'Karen Frazier', 'Dave Grohl', 'Adam Silvera',
#        'E. Lockhart', 'Suzanne Lang', 'Megan Logan MSW  LCSW',
#        'Jenson William', 'Scholastic Teacher Resources',
#        'Dr. Nicole LePera', 'Adam Grant', 'Sanjay Gupta M.D.',
#        'Shannon Bream', 'V. E. Schwab', 'Emily Henry', 'Marilyn Sadler',
#        'Joshua Weissman', 'Eckhart Tolle', 'Jeffrey Eisner', 'Will Smith',
#        'Napoleon Hill', 'Doctor Joseph Mercola'], dtype=object)

# %%
books_df.shape
# Out:
# (1285, 9)

# %%
books_df.cover_type.unique()
# Out:
# array(['Hardcover', 'Paperback', 'Mass Market Paperback', 'Spiral-bound',
#        'Board book', 'Printed Access Code', 'Pamphlet', 'Cards'],
#       dtype=object)

# %%
sns.countplot(x='genre', data=books_df)
# Out:
# <AxesSubplot:xlabel='genre', ylabel='count'>

# %%
plt.figure(figsize=(14, 6))
sns.countplot(x='cover_type', data=books_df)
# Out:
# <AxesSubplot:xlabel='cover_type', ylabel='count'>

# %%
num_vars= [ 'price','no_of_reviews','ratings','ranks']       # numerical variables of interest
cat_vars = ['genre','cover_type']

# %%
g = sns.PairGrid(data=books_df, vars=num_vars)
g = g.map_diag(plt.hist, bins=50)
g.map_offdiag(plt.scatter)

# %%
sns.countplot(data=books_df, y='cover_type', hue='genre', palette='Blues')
# Out:
# <AxesSubplot:xlabel='count', ylabel='cover_type'>

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=books_df, x='year', hue='genre', palette='Blues')
plt.legend(ncol=1)
plt.legend(loc =2 , ncol =5)

# %%
books_df[books_df['genre'] == 'unknown']
# Out:
#      price  ranks                                              title  \
# 289  20.61   97.0  Moleskine Classic Notebook, Hard Cover, Large ...
# 714   8.99   23.0  Adult Coloring Book Designs: Stress Relief Col...
#
#      no_of_reviews  ratings                       author cover_type  year  \
# 289        22268.0      4.8              Moleskine Store  Hardcover  2011
# 714         3113.0      4.5  Adult Coloring Book Designs  Paperback  2016
#
#        genre
# 289  unknown
# 714  unknown

# %%
books_df.genre.shape
# Out:
# (1285,)

# %%
books_df[books_df.genre.str.contains('unknown')]
# Out:
#      price  ranks                                              title  \
# 289  20.61   97.0  Moleskine Classic Notebook, Hard Cover, Large ...
# 714   8.99   23.0  Adult Coloring Book Designs: Stress Relief Col...
#
#      no_of_reviews  ratings                       author cover_type  year  \
# 289        22268.0      4.8              Moleskine Store  Hardcover  2011
# 714         3113.0      4.5  Adult Coloring Book Designs  Paperback  2016
#
#        genre
# 289  unknown
# 714  unknown

# %%
# Drop unknown data in genre column
books_df.where(~(books_df.genre.str.contains('unknown')), np.nan, inplace=True)

# %%
import plotly.express as px

# %%
books_df.groupby('genre')['title']

# %%
temp = books_df.groupby('genre')['title'].agg('count').reset_index()

# %%
temp.columns = ['genre', 'title']

# %%
temp
# Out:
#          genre  title
# 0      Fiction    560
# 1  Non Fiction    723

# %%
px.pie(temp, labels='genre', values='title', hover_data=['genre'],title="Categories of the books")

# %%
plt.pie(data=temp,x='title', labels='genre', autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x21d4c465d48>,
#   <matplotlib.patches.Wedge at 0x21d4c47c608>],
#  [Text(0.2180655270814787, 1.078168551711038, 'Fiction'),
#   Text(-0.21806552708147883, -1.078168551711038, 'Non Fiction')],
#  [Text(0.11894483295353382, 0.5880919372969297, '43.6%'),
#   Text(-0.11894483295353389, -0.5880919372969297, '56.4%')])
